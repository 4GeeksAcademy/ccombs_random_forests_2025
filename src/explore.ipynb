# %% [markdown]
# # Exploring Random Forests

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import recall_score, precision_score, f1_score, accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split, GridSearchCV

from sklearn.ensemble import RandomForestClassifier

# %%
main_df = pd.read_csv("https://breathecode.herokuapp.com/asset/internal-link?id=421&path=diabetes.csv")

# %%
main_df.head(3)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1

# %%
train_df, test_df = train_test_split(main_df, test_size=0.17, random_state=4)

# %%
main_df.shape
# Out:
# (768, 9)

# %%
train_df.shape
# Out:
# (614, 9)

# %%
X_train = train_df.drop(columns="Outcome")
y_train = train_df["Outcome"]

X_test = test_df.drop(columns="Outcome")
y_test = test_df["Outcome"]

# %%
#this function makes predictions and prints out various evaluation metrics
def model_evaluator(X_matrix, y_target, model):
    preds = model.predict(X_matrix)
    
    print(f"Accuracy score: {round(accuracy_score(y_true = y_target, y_pred = preds),4)}")
    print(f"Precision score: {round(precision_score(y_true = y_target, y_pred = preds),4)}")
    print(f"Recall score: {round(recall_score(y_true = y_target, y_pred = preds),4)}")
    print(f"F1 score:{round(f1_score(y_true = y_target, y_pred = preds),4)}")
    print(f"Confusion matrix: \n{confusion_matrix(y_true = y_target, y_pred = preds)}")
    print(f"Classification report: \n{classification_report(y_true = y_target, y_pred = preds)}")

# %%
rf_model = RandomForestClassifier(random_state=101)

rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=101)

# %%
model_evaluator(X_train, y_train, rf_model)
# Out:
# Accuracy score: 1.0
# Precision score: 1.0
# Recall score: 1.0
# F1 score:1.0
# Confusion matrix:
# [[413   0]
#  [  0 224]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       413
#            1       1.00      1.00      1.00       224
#
#     accuracy                           1.00       637
#    macro avg       1.00      1.00      1.00       637
# weighted avg       1.00      1.00      1.00       637

# %%
model_evaluator(X_test, y_test, rf_model)
# Out:
# Accuracy score: 0.7863
# Precision score: 0.7222
# Recall score: 0.5909
# F1 score:0.65
# Confusion matrix:
# [[77 10]
#  [18 26]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.89      0.85        87
#            1       0.72      0.59      0.65        44
#
#     accuracy                           0.79       131
#    macro avg       0.77      0.74      0.75       131
# weighted avg       0.78      0.79      0.78       131

# %%
np.round(pd.DataFrame(rf_model.feature_importances_, rf_model.feature_names_in_) * 100, 2)
# Out:
#                               0
# Pregnancies                8.85
# Glucose                   23.69
# BloodPressure              9.31
# SkinThickness              7.03
# Insulin                    7.61
# BMI                       16.74
# DiabetesPedigreeFunction  12.55
# Age                       14.23

# %% [markdown]
# ### Our Random Forest model is overfitting on the training data, Let's tune the hyperparameters

# %%
hyperparameter_dict = {
    "n_estimators": [20, 30, 100, 275],
    "max_depth": [None, 3, 5],
    "min_samples_split": [2, 6, 18],
    "min_samples_leaf": [2, 6, 18],
    "max_features": [None, 1, 6],
}

# %%
gridsearch_model = GridSearchCV(estimator=RandomForestClassifier(), 
                                    param_grid=hyperparameter_dict, 
                                    scoring="accuracy", 
                                    verbose=3,
                                    cv=2)

# %%
gridsearch_model.fit(X_train, y_train)
# Out:
# Fitting 2 folds for each of 324 candidates, totalling 648 fits
# [CV 1/2] END max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=20;, score=0.765 total time=   0.0s
# [CV 2/2] END max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=20;, score=0.726 total time=   0.0s
# [CV 1/2] END max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=30;, score=0.771 total time=   0.1s
# [CV 2/2] END max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=30;, score=0.733 total time=   0.1s
# [CV 1/2] END max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.762 total time=   0.2s
# [CV 2/2] END max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.758 total time=   0.2s
# [CV 1/2] END max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=275;, score=0.765 total time=   0.5s
# [CV 2/2] END max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=2, n_estimators=275;, score=0.739 total time=   0.5s
# [CV 1/2] END max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=20;, score=0.743 total time=   0.0s
# [CV 2/2] END max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=20;, score=0.755 total time=   0.0s
# [CV 1/2] END max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=30;, score=0.771 total time=   0.1s
# [CV 2/2] END max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=30;, score=0.736 total time=   0.1s
# [CV 1/2] END max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=100;, score=0.768 total time=   0.2s
# [CV 2/2] END max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=100;, score=0.742 total time=   0.2s
# [CV 1/2] END max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=275;, score=0.774 total time=   0.4s
# [CV 2/2] END max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=6, n_estimators=275;, score=0.748 total time=   0.4s
# [CV 1/2] END max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split=18, n_estimators=20;, score=0.749 total time=   0.0s
# [CV 2/2] END max_depth=None, max_features=None, min_samples_leaf=2, min_samples_split
total time=   0.0s
# [CV 1/2] END max_depth=5, max_features=6, min_samples_leaf=2, min_samples_split=6, n_estimators=100;, score=0.774 total time=   0.1s
# [CV 2/2] END max_depth=5, max_features=6, min_samples_leaf=2, min_samples_split=6, n_estimators=100;, score=0.758 total time=   0.1s
# [CV 1/2] END max_depth=5, max_features=6, min_samples_leaf=2, min_samples_split=6, n_estimators=275;, score=0.774 total time=   0.5s
# [CV 2/2] END max_depth=5, max_features=6, min_samples_leaf=2, min_samples_split=6, n_estimators=275;, score=0.752 total time=   0.4s
# [CV 1/2] END max_depth=5, max_features=6, min_samples_leaf=2, min_samples_split=18, n_estimators=20;, score=0.781 total time=   0.0s
# [CV 2/2] END max_depth=5, max_features=6, min_samples_leaf=2, min_samples_split=18, n_estimators=20;, score=0.745 total time=   0.0s
# [CV 1/2] END max_depth=5, max_features=6, min_samples_leaf=2, min_samples_split=18, n_estimators=30;, score=0.777 total time=   0.0s
# [CV 2/2] END max_depth=5, max_features=6, min_samples_leaf=2, min_samples_split=18, n_estimators=30;, score=0.739 total time=   0.0s
# [CV 1/2] END max_depth=5, max_features=6, min_samples_leaf=2, min_samples_split=18, n_estimators=100;, score=0.765 total time=   0.1s
# [CV 2/2] END max_depth=5, max_features=6, min_samples_leaf=2, min_samples_split=18, n_estimators=100;, score=0.745 total time=   0.1s
# [CV 1/2] END max_depth=5, max_features=6, min_samples_leaf=2, min_samples_split=18, n_estimators=275;, score=0.771 total time=   0.4s
# [CV 2/2] END max_depth=5, max_features=6, min_samples_leaf=2, min_samples_split=18, n_estimators=275;, score=0.748 total time=   0.4s
# [CV 1/2] END max_depth=5, max_features=6, min_samples_leaf=6, min_samples_split=2, n_estimators=20;, score=0.787 total time=   0.0s
# [CV 2/2] END max_depth=5, max_features=6, min_samples_leaf=6, min_samples_split=2, n_estimators=20;, score=0.758 total time=   0.0s
# [CV 1/2] END max_depth=5, max_features=6, min_samples_leaf=6, min_samples_split=2, n_estimators=30;, score=0.777 total time=   0.0s
# [CV 2/2] END max_depth=5, max_features=6, min_samples_leaf=6, min_samples_split=2, n_estimators=30;, score=0.745 total time=   0.0s
# [CV 1/2] END max_depth=5, max_features=6, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.774 total time=   0.1s
# [CV 2/2] END max_depth=5, max_features=6, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.739 total time=   0.1s
# [CV 1/2] END max_depth=5, max_features=6, min_samples_leaf=6, min_samples_split=2, n_estimators=275;, score=0.777 total time=   0.4s
# [CV 2/2] END max_depth=5, max_features=6, min_samples_leaf=6, min_samples_split=2, n_estimators=275;, score=0.742 total time=   0.4s
# [CV 1/2] END max_depth=5, max_features=6, min_samples_leaf=6, min_samples_split=6, n_estimators=20;, score=0.787 total time=   0.0s
# [CV 2/2] END max_depth=5, max_features=6, min_samples_leaf=6, min_samples_split=6, n_estimators=20;, score=0.758 total time=   0.0s
# [CV 1/2] END max_depth=5, max_features=6, min_samples_leaf=6, min_samples_split=6, n_estimators=30;, score=0.762 total time=   0.0s
# [CV 2/2] END max_depth=5, max_features=6, min_samples_leaf=6, min_samples_split=6, n_estimators=30;, score=0.739 total time=   0.0s
# [CV 1/2] END max_depth=5, max_features=6, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.774 total time=   0.1s
# [CV 2/2] END max_depth=5, max_features=6, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.752 total time=   0.1s
# [CV 1/2] END max_depth=5, max_features=6, min_samples_leaf=6, min_samples_split=6, n_estimators=275;, score=0.781 total time=   0.4s
# [CV 2/2] END max_depth=5, max_features=6, min_samples_leaf=6, min_samples_split=6, n_estimators=275;, score=0.736 total time=   0.4s
# [CV 1/2] END max_depth=5, max_features=6, min_samples_leaf=6, min_samples_split=18, n_estimators=20;, score=0.774 total time=   0.0s
# [CV 2/2] END max_depth=5, max_features=6, min_samples_leaf=6, min_samples_split=18, n_estimators=20;, score=0.748 total time=   0.0s
# [CV 1/2] END max_depth=5, max_features=6, min_samples_leaf=6, min_samples_split=18, n_estimators=30;, score=0.768 total time=   0.0s
# [CV 2/2] END max_depth=5, max_features=6, min_samples_leaf=6, min_samples_split=18, n_estimators=30;, score=0.748 total time=   0.0s
# [CV 1/2] END max_depth=5, max_features=6, min_samples_leaf=6, min_samples_split=18, n_estimators=100;, score=0.787 total time=   0.1s
# [CV 2/2] END max_depth=5, max_features=6, min_samples_leaf=6, min_samples_split=18, n_estimators=100;, score=0.752 total time=   0.1s
# [CV 1/2] END max_depth=5, max_features=6, min_samples_leaf=6, min_samples_split=18, n_estimators=275;, score=0.790 total time=   0.3s
# [CV 2/2] END max_depth=5, max_features=6, min_samples_leaf=6, min_samples_split=18, n_estimators=275;, score=0.736 total time=   0.3s
# [CV 1/2] END max_depth=5, max_features=6, min_samples_leaf=18, min_samples_split=2, n_estimators=20;, score=0.781 total time=   0.0s
# [CV 2/2] END max_depth=5, max_features=6, min_samples_leaf=18, min_samples_split=2, n_estimators=20;, score=0.739 total time=   0.0s
# [CV 1/2] END max_depth=5, max_features=6, min_samples_leaf=18, min_samples_split=2, n_estimators=30;, score=0.790 total time=   0.0s
# [CV 2/2] END max_depth=5, max_features=6, min_samples_leaf=18, min_samples_split=2, n_estimators=30;, score=0.742 total time=   0.0s
# [CV 1/2] END max_depth=5, max_features=6, min_samples_leaf=18, min_samples_split=2, n_estimators=100;, score=0.784 total time=   0.1s
# [CV 2/2] END max_depth=5, max_features=6, min_samples_leaf=18, min_samples_split=2, n_estimators=100;, score=0.739 total time=   0.1s
# [CV 1/2] END max_depth=5, max_features=6, min_samples_leaf=18, min_samples_split=2, n_estimators=275;, score=0.777 total time=   0.3s
# [CV 2/2] END max_depth=5, max_features=6, min_samples_leaf=18, min_samples_split=2, n_estimators=275;, score=0.739 total time=   0.3s
# [CV 1/2] END max_depth=5, max_features=6, min_samples_leaf=18, min_samples_split=6, n_estimators=20;, score=0.787 total time=   0.0s
# [CV 2/2] END max_depth=5, max_features=6, min_samples_leaf=18, min_samples_split=6, n_estimators=20;, score=0.733 total time=   0.0s
# [CV 1/2] END max_depth=5, max_features=6, min_samples_leaf=18, min_samples_split=6, n_estimators=30;, score=0.787 total time=   0.0s
# [CV 2/2] END max_depth=5, max_features=6, min_samples_leaf=18, min_samples_split=6, n_estimators=30;, score=0.730 total time=   0.0s
# [CV 1/2] END max_depth=5, max_features=6, min_samples_leaf=18, min_samples_split=6, n_estimators=100;, score=0.796 total time=   0.1s
# [CV 2/2] END max_depth=5, max_features=6, min_samples_leaf=18, min_samples_split=6, n_estimators=100;, score=0.730 total time=   0.1s
# [CV 1/2] END max_depth=5, max_features=6, min_samples_leaf=18, min_samples_split=6, n_estimators=275;, score=0.784 total time=   0.3s
# [CV 2/2] END max_depth=5, max_features=6, min_samples_leaf=18, min_samples_split=6, n_estimators=275;, score=0.736 total time=   0.3s
# [CV 1/2] END max_depth=5, max_features=6, min_samples_leaf=18, min_samples_split=18, n_estimators=20;, score=0.784 total time=   0.0s
# [CV 2/2] END max_depth=5, max_features=6, min_samples_leaf=18, min_samples_split=18, n_estimators=20;, score=0.748 total time=   0.1s
# [CV 1/2] END max_depth=5, max_features=6, min_samples_leaf=18, min_samples_split=18, n_estimators=30;, score=0.784 total time=   0.1s
# [CV 2/2] END max_depth=5, max_features=6, min_samples_leaf=18, min_samples_split=18, n_estimators=30;, score=0.739 total time=   0.0s
# [CV 1/2] END max_depth=5, max_features=6, min_samples_leaf=18, min_samples_split=18, n_estimators=100;, score=0.790 total time=   0.2s
# [CV 2/2] END max_depth=5, max_features=6, min_samples_leaf=18, min_samples_split=18, n_estimators=100;, score=0.739 total time=   0.3s
# [CV 1/2] END max_depth=5, max_features=6, min_samples_leaf=18, min_samples_split=18, n_estimators=275;, score=0.790 total time=   0.3s
# [CV 2/2] END max_depth=5, max_features=6, min_samples_leaf=18, min_samples_split=18, n_estimators=275;, score=0.733 total time=   0.5s
# GridSearchCV(cv=2, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [None, 3, 5],
#                          'max_features': [None, 1, 6],
#                          'min_samples_leaf': [2, 6, 18],
#                          'min_samples_split': [2, 6, 18],
#                          'n_estimators': [20, 30, 100, 275]},
#              scoring='accuracy', verbose=3)

# %%
# first set of training data @ 20%
model_evaluator(X_train, y_train, gridsearch_model)
# Out:
# Accuracy score: 0.772
# Precision score: 0.7468
# Recall score: 0.5324
# F1 score:0.6216
# Confusion matrix:
# [[359  39]
#  [101 115]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.90      0.84       398
#            1       0.75      0.53      0.62       216
#
#     accuracy                           0.77       614
#    macro avg       0.76      0.72      0.73       614
# weighted avg       0.77      0.77      0.76       614

# %%
# first set of training data @ 20%
model_evaluator(X_test, y_test, gridsearch_model)
# Out:
# Accuracy score: 0.8247
# Precision score: 0.7551
# Recall score: 0.7115
# F1 score:0.7327
# Confusion matrix:
# [[90 12]
#  [15 37]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.88      0.87       102
#            1       0.76      0.71      0.73        52
#
#     accuracy                           0.82       154
#    macro avg       0.81      0.80      0.80       154
# weighted avg       0.82      0.82      0.82       154

# %%
np.round(pd.DataFrame(gridsearch_model.best_estimator_.feature_importances_,gridsearch_model.feature_names_in_)*100,2).sort_values(by=0, ascending=False)
# Out:
#                               0
# Glucose                   58.10
# BMI                       18.15
# Age                       15.00
# DiabetesPedigreeFunction   4.62
# Pregnancies                1.65
# SkinThickness              1.35
# Insulin                    0.75
# BloodPressure              0.37

# %%
# second set of training data @ 15%
model_evaluator(X_train, y_train, gridsearch_model)
# Out:
# Accuracy score: 0.7807
# Precision score: 0.7515
# Recall score: 0.557
# F1 score:0.6398
# Confusion matrix:
# [[382  42]
#  [101 127]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.90      0.84       424
#            1       0.75      0.56      0.64       228
#
#     accuracy                           0.78       652
#    macro avg       0.77      0.73      0.74       652
# weighted avg       0.78      0.78      0.77       652

# %%
# second set of training data @ 15%
model_evaluator(X_test, y_test, gridsearch_model)
# Out:
# Accuracy score: 0.8017
# Precision score: 0.7576
# Recall score: 0.625
# F1 score:0.6849
# Confusion matrix:
# [[68  8]
#  [15 25]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.86        76
#            1       0.76      0.62      0.68        40
#
#     accuracy                           0.80       116
#    macro avg       0.79      0.76      0.77       116
# weighted avg       0.80      0.80      0.80       116

# %%
# third set of training data @ 25%
model_evaluator(X_train, y_train, gridsearch_model)
# Out:
# Accuracy score: 0.9028
# Precision score: 0.8842
# Recall score: 0.8317
# F1 score:0.8571
# Confusion matrix:
# [[352  22]
#  [ 34 168]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.93       374
#            1       0.88      0.83      0.86       202
#
#     accuracy                           0.90       576
#    macro avg       0.90      0.89      0.89       576
# weighted avg       0.90      0.90      0.90       576

# %%
# third set of training data @ 25%
model_evaluator(X_test, y_test, gridsearch_model)
# Out:
# Accuracy score: 0.7917
# Precision score: 0.6857
# Recall score: 0.7273
# F1 score:0.7059
# Confusion matrix:
# [[104  22]
#  [ 18  48]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84       126
#            1       0.69      0.73      0.71        66
#
#     accuracy                           0.79       192
#    macro avg       0.77      0.78      0.77       192
# weighted avg       0.80      0.79      0.79       192

# %%
# fourth set of training data @ 17%
model_evaluator(X_train, y_train, gridsearch_model)
# Out:
# Accuracy score: 0.7786
# Precision score: 0.7485
# Recall score: 0.558
# F1 score:0.6394
# Confusion matrix:
# [[371  42]
#  [ 99 125]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.90      0.84       413
#            1       0.75      0.56      0.64       224
#
#     accuracy                           0.78       637
#    macro avg       0.77      0.73      0.74       637
# weighted avg       0.77      0.78      0.77       637

# %%
# fourth set of training data @ 17%
model_evaluator(X_test, y_test, gridsearch_model)
# Out:
# Accuracy score: 0.8092
# Precision score: 0.7317
# Recall score: 0.6818
# F1 score:0.7059
# Confusion matrix:
# [[76 11]
#  [14 30]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.87      0.86        87
#            1       0.73      0.68      0.71        44
#
#     accuracy                           0.81       131
#    macro avg       0.79      0.78      0.78       131
# weighted avg       0.81      0.81      0.81       131
